# %%
from helpers.graph import draw_graph
from memory.long_term_graph_memory import GraphWithMemory

agent = GraphWithMemory()
agent.build()
draw_graph(agent.graph)

# %%
def pretty_print_stream_chunk(chunk):
    for node, updates in chunk.items():
        print(f"Update from node: {node}")
        if "messages" in updates:
            updates["messages"][-1].pretty_print()
        else:
            print(updates)

        print("\n")

# %%
# NOTE: we're specifying `user_id` to save memories for a given user
config = {"configurable": {"user_id": "1", "thread_id": "1"}}

for chunk in agent.graph.stream({"messages": "What is the sales by department for last year"}, config=config):
    pretty_print_stream_chunk(chunk)
# Out:
# Update from node: load_memories
# {'recall_memories': []}
#
#
# Update from node: agent
# ================================== Ai Message ==================================
#
# Could you please specify which department or departments you're interested in? Additionally, if you have a particular company or organization in mind, that would help narrow it down.
